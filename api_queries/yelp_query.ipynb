# %%
# Yelp API tutorial: https://python.gotrained.com/yelp-fusion-api-tutorial/

# %%
import requests
import json

# %%
api_key='gPWslag3JTblGMOVOLoyWFXn7PwrZ10M5Z4j-Ej54KeW2Svd2vrxdEz_Jpl3ls09mii6uZcl1vD89TwD23DaA3Qj01xQtLsVIzz9HqZge0tjGyUiWvU_lhbb5LzmXXYx'
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
# params = ['id','alias','name','is_closed','review_count','rating','price',
#           'categories',         
#           'coordinates',
#           'location']

# %%
# businesses search -- search term "nightlife" in Astoria

url='https://api.yelp.com/v3/businesses/search'
params={'term':'nightlife', 'location':'Astoria'}

# %%
req = requests.get(url, params=params, headers=headers)

# %%
parsed = json.loads(req.text)

# %%
print(json.dumps(parsed, indent=4))
# Out:
# {
#     "businesses": [
#         {
#             "id": "O7CnII31QnhLIYoUlOXrZA",
#             "alias": "la-sala-astoria",
#             "name": "La Sala",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/DZKzPRQZV-q1P6PXKFvaaA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/la-sala-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 123,
#             "categories": [
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 },
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 },
#                 {
#                     "alias": "beer_and_wine",
#                     "title": "Beer, Wine & Spirits"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.7632006,
#                 "longitude": -73.9286183
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "3205 Crescent St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Astoria",
#                 "zip_code": "11106",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "3205 Crescent St",
#                     "Astoria, NY 11106"
#                 ]
#             },
#             "phone": "+17186066121",
#             "display_phone": "(718) 606-6121",
#             "distance": 678.8091676380677
#         },
#         {
#             "id": "TI5dWiHdFn55WQDmvffu0Q",
#             "alias": "the-lingerie-shoppe-aka-astoria-s-secret-queens",
#             "name": "The Lingerie Shoppe aka Astoria\u2019s Secret",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/QnthqKdgqQMHv7bKSDLdhw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-lingerie-shoppe-aka-astoria-s-secret-queens?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 10,
#             "categories": [
#                 {
#                     "alias": "speakeasies",
#                     "title": "Speakeasies"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.76406,
#                 "longitude": -73.9145
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "28-53 Steinway St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Queens",
#                 "zip_code": "11103",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "28-53 Steinway St",
#                     "Queens, NY 11103"
#                 ]
#             },
#             "phone": "",
#             "display_phone": "",
#             "distance": 722.0754068691086
#         },
#         {
#             "id": "am1ba1kfJ-Sn_G2cY6c8KA",
#             "alias": "hangar-astoria-astoria",
#             "name": "Hangar Astoria",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/o34l0QHFAp_9sh63r36FOA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/hangar-astoria-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 62,
#             "categories": [
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 },
#                 {
#                     "alias": "sportsbars",
#                     "title": "Sports Bars"
#                 },
#                 {
#                     "alias": "tapas",
#                     "title": "Tapas Bars"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 40.76427,
#                 "longitude": -73.91428
#             },
#             "transactions": [
#                 "restaurant_reservation",
#                 "pickup",
#                 "delivery"
#             ],
#             "location": {
#                 "address1": "28-43 Steinway St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Astoria",
#                 "zip_code": "11103",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "28-43 Steinway St",
#                     "Astoria, NY 11103"
#                 ]
#             },
#             "phone": "+19173964308",
#             "display_phone": "(917) 396-4308",
#             "distance": 723.6851533129385
#         },
#         {
#             "id": "W0sXHSSpkiMEDJiBmSLNYQ",
#             "alias": "trestle-astoria",
#             "name": "Trestle",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/OQZ2Ej77vt74KQ9DCPxuzA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/trestle-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 310,
#             "categories": [
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.7606154,
#                 "longitude": -73.9229562
#             },
#             "transactions": [
#                 "restaurant_reservation",
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "34-02 Broadway",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Astoria",
#                 "zip_code": "11106",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "34-02 Broadway",
#                     "Astoria, NY 11106"
#                 ]
#             },
#             "phone": "+13478080290",
#             "display_phone": "(347) 808-0290",
#             "distance": 700.5006551209126
#         },
#         {
#             "id": "DB45nM2VMUocjPejFArc1g",
#             "alias": "the-social-astoria",
#             "name": "The Social",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/yB4wta3fFcUGl_TgabGmRQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-social-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 72,
#             "categories": [
#                 {
#                     "alias": "tapasmallplates",
#                     "title": "Tapas/Small Plates"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.76434,
#                 "longitude": -73.91655
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "37-06 30th Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Astoria",
#                 "zip_code": "11103",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "37-06 30th Ave",
#                     "Astoria, NY 11103"
#                 ]
#             },
#             "phone": "+17187723777",
#             "display_phone": "(718) 772-3777",
#             "distance": 559.1471932704986
#         },
#         {
#             "id": "CM8WhuCoXd3j3u4Jjqol-g",
#             "alias": "savanna-rooftop-long-island-city",
#             "name": "Savanna Rooftop",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/FgDzcfljjwhDjzWC9GJX5A/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/savanna-rooftop-long-island-city?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 88,
#             "categories": [
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 },
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.75198,
#                 "longitude": -73.94752
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "11-01 43rd Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Long Island City",
#                 "zip_code": "11101",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "11-01 43rd Ave",
#                     "Long Island City, NY 11101"
#                 ]
#             },
#             "phone": "+17185689860",
#             "display_phone": "(718) 568-9860",
#             "distance": 2681.621182207506
#         },
#         {
#             "id": "if1p9GpT78JbgcduQzzRYw",
#             "alias": "1-degree-up-astoria",
#             "name": "1 Degree UP",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/msdIX1vw6p6dGE9AjTZ1_Q/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/1-degree-up-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 53,
#             "categories": [
#                 {
#                     "alias": "asianfusion",
#                     "title": "Asian Fusion"
#                 },
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 40.76824,
#                 "longitude": -73.92086
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "30-07 Newtown Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Astoria",
#                 "zip_code": "11102",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "30-07 Newtown Ave",
#                     "Astoria, NY 11102"
#                 ]
#             },
#             "phone": "+17186660009",
#             "display_phone": "(718) 666-0009",
#             "distance": 188.73321467846912
#         },
#         {
#             "id": "vCkDS0X-fWApvTS1Qyxjnw",
#             "alias": "taj-mahal-lounge-astoria",
#             "name": "Taj Mahal Lounge",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/jmeIpBFd_JY43urCKHLi1g/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/taj-mahal-lounge-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 46,
#             "categories": [
#                 {
#                     "alias": "hookah_bars",
#                     "title": "Hookah Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.76706,
#                 "longitude": -73.91204
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "25-27 Steinway St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Astoria",
#                 "zip_code": "11103",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "25-27 Steinway St",
#                     "Astoria, NY 11103"
#                 ]
#             },
#             "phone": "+17187281950",
#             "display_phone": "(718) 728-1950",
#             "distance": 857.5621890838905
#         },
#         {
#             "id": "Ti9A-_WMY_swFRTzX1h56A",
#             "alias": "d\u00e9j\u00e0-vu-astoria-7",
#             "name": "D\u00e9j\u00e0 Vu",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/e55bvjZ7iXoYWXLpx9BLnA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/d%C3%A9j%C3%A0-vu-astoria-7?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 110,
#             "categories": [
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 },
#                 {
#                     "alias": "hookah_bars",
#                     "title": "Hookah Bars"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.7674757,
#                 "longitude": -73.918271
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "3322 28th Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Astoria",
#                 "zip_code": "11103",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "3322 28th Ave",
#                     "Astoria, NY 11103"
#                 ]
#             },
#             "phone": "+17182678212",
#             "display_phone": "(718) 267-8212",
#             "distance": 363.0923661896718
#         },
#         {
#             "id": "k5bGHJbAXDw9g_uP42QqDw",
#             "alias": "the-highwater-astoria",
#             "name": "The Highwater",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/aBnUr0gnSK6TBRwvmD94lQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-highwater-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 354,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "hawaiian",
#                     "title": "Hawaiian"
#                 },
#                 {
#                     "alias": "tikibars",
#                     "title": "Tiki Bars"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.76033,
#                 "longitude": -73.92245
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "3420 Broadway",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Astoria",
#                 "zip_code": "11106",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "3420 Broadway",
#                     "Astoria, NY 11106"
#                 ]
#             },
#             "phone": "+19177450407",
#             "display_phone": "(917) 745-0407",
#             "distance": 725.2673126671355
#         },
#         {
#             "id": "VeqLibXJertB2gRcyIY00w",
#             "alias": "tantra-lounge-astoria",
#             "name": "Tantra Lounge",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/zRK3atR7tJj2_j2KfOLQAQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/tantra-lounge-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 77,
#             "categories": [
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 },
#                 {
#                     "alias": "hookah_bars",
#                     "title": "Hookah Bars"
#                 }
#             ],
#             "rating": 3.0,
#             "coordinates": {
#                 "latitude": 40.757,
#                 "longitude": -73.9298
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "35-50 31st St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Astoria",
#                 "zip_code": "11106",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "35-50 31st St",
#                     "Astoria, NY 11106"
#                 ]
#             },
#             "phone": "+17189374574",
#             "display_phone": "(718) 937-4574",
#             "distance": 1273.4714407718184
#         },
#         {
#             "id": "WRPrwGH50FBm7yiuYKiLjw",
#             "alias": "mosaic-craft-cocktail-beer-and-wine-bar-astoria",
#             "name": "Mosaic Craft Cocktail, Beer & Wine Bar",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/CwtajADcnN7U5TFYuzuIzg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/mosaic-craft-cocktail-beer-and-wine-bar-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 286,
#             "categories": [
#                 {
#                     "alias": "beerbar",
#                     "title": "Beer Bar"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.7746577,
#                 "longitude": -73.9183673
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "25-19 24th Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Astoria",
#                 "zip_code": "11102",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "25-19 24th Ave",
#                     "Astoria, NY 11102"
#                 ]
#             },
#             "phone": "+17187280708",
#             "display_phone": "(718) 728-0708",
#             "distance": 922.0565344074737
#         },
#         {
#             "id": "gK-d-vOz9UmXIE_08jEOzg",
#             "alias": "the-bad-ass-astoria",
#             "name": "The Bad Ass",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/CwCB39b-lj14nq0eyH1YRA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-bad-ass-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 4,
#             "categories": [
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.77632,
#                 "longitude": -73.91518
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "26-17 23rd Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Astoria",
#                 "zip_code": "11105",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "26-17 23rd Ave",
#                     "Astoria, NY 11105"
#                 ]
#             },
#             "phone": "+17184408378",
#             "display_phone": "(718) 440-8378",
#             "distance": 1204.2774146991496
#         },
#         {
#             "id": "liaw_m73XvOmEiB8e1Vqkw",
#             "alias": "don-coqui-astoria-queens-3",
#             "name": "Don Coqui Astoria",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/_bpPaon-22BrY-5Ys00z7A/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/don-coqui-astoria-queens-3?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 1601,
#             "categories": [
#                 {
#                     "alias": "latin",
#                     "title": "Latin American"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "rating": 3.0,
#             "coordinates": {
#                 "latitude": 40.768219,
#                 "longitude": -73.920504
#             },
#             "transactions": [
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "18 31st St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Queens",
#                 "zip_code": "11102",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "18 31st St",
#                     "Queens, NY 11102"
#                 ]
#             },
#             "phone": "+17182747474",
#             "display_phone": "(718) 274-7474",
#             "distance": 205.3524889511799
#         },
#         {
#             "id": "cuVyM_ZxtREqpO1SXgZmRA",
#             "alias": "bohemian-hall-and-beer-garden-astoria",
#             "name": "Bohemian Hall & Beer Garden",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/e2EKZMOuVYafUBSvBa87HA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/bohemian-hall-and-beer-garden-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 1132,
#             "categories": [
#                 {
#                     "alias": "venues",
#                     "title": "Venues & Event Spaces"
#                 },
#                 {
#                     "alias": "beergardens",
#                     "title": "Beer Gardens"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.77273,
#                 "longitude": -73.915772
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "2919 24th Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Astoria",
#                 "zip_code": "11102",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "2919 24th Ave",
#                     "Astoria, NY 11102"
#                 ]
#             },
#             "phone": "+17182744925",
#             "display_phone": "(718) 274-4925",
#             "distance": 845.2681265996333
#         },
#         {
#             "id": "KqxBfDaww1j0qhgDGh-VSg",
#             "alias": "diamond-dogs-astoria",
#             "name": "Diamond Dogs",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/cp5C_NMqJEcof79o6fb7sw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/diamond-dogs-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 133,
#             "categories": [
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 },
#                 {
#                     "alias": "beergardens",
#                     "title": "Beer Gardens"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.76285,
#                 "longitude": -73.92099
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "34-04 31st Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Astoria",
#                 "zip_code": "11106",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "34-04 31st Ave",
#                     "Astoria, NY 11106"
#                 ]
#             },
#             "phone": "+19295220061",
#             "display_phone": "(929) 522-0061",
#             "distance": 437.5630623418546
#         },
#         {
#             "id": "hsOssMippVdSL_-nmjBUtw",
#             "alias": "ritmos-60-astoria",
#             "name": "Ritmos 60",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/Vlol9j-k23Y1dyeHNWkzug/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/ritmos-60-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 24,
#             "categories": [
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "rating": 3.0,
#             "coordinates": {
#                 "latitude": 40.758482,
#                 "longitude": -73.919373
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "32-23 Steinway St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Astoria",
#                 "zip_code": "11103",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "32-23 Steinway St",
#                     "Astoria, NY 11103"
#                 ]
#             },
#             "phone": "+17182041110",
#             "display_phone": "(718) 204-1110",
#             "distance": 964.5376405675175
#         },
#         {
#             "id": "Q_bI2gY7LtMCXkzkakPUkg",
#             "alias": "henrys-rooftop-bar-new-york",
#             "name": "Henry's Rooftop Bar",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/_icYfdoRPXIwzQGdaqFJ-A/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/henrys-rooftop-bar-new-york?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 60,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.754799,
#                 "longitude": -73.97314
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "501 Lexington Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10017",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "501 Lexington Ave",
#                     "New York, NY 10017"
#                 ]
#             },
#             "phone": "+12127551400",
#             "display_phone": "(212) 755-1400",
#             "distance": 4496.395478053586
#         },
#         {
#             "id": "MWPtdS9XHmAFLMMuWaD0tg",
#             "alias": "the-spot-astoria",
#             "name": "The Spot",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Mtu8bB_khhci2DBZEIuSyw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-spot-astoria?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 5,
#             "categories": [
#                 {
#                     "alias": "hookah_bars",
#                     "title": "Hookah Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.75807,
#                 "longitude": -73.91657
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "42-21 Broadway",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Astoria",
#                 "zip_code": "11103",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "42-21 Broadway",
#                     "Astoria, NY 11103"
#                 ]
#             },
#             "phone": "+17182046811",
#             "display_phone": "(718) 204-6811",
#             "distance": 1088.4158373629832
#         },
#         {
#             "id": "iOi6-KC3dyBAE_Bbgokyxw",
#             "alias": "vibras-restaurant-and-lounge-new-york",
#             "name": "Vibras Restaurant & Lounge",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/q73cQPGpp8civncS37Sw7w/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/vibras-restaurant-and-lounge-new-york?adjust_creative=xC4n-h7ZGIsND4SXpQ_Fzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xC4n-h7ZGIsND4SXpQ_Fzg",
#             "review_count": 1,
#             "categories": [
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 }
#             ],
#             "rating": 5.0,
#             "coordinates": {
#                 "latitude": 40.76377,
#                 "longitude": -73.87815
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "91-01 Astoria Blvd",
#                 "address2": null,
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "11369",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "91-01 Astoria Blvd",
#                     "New York, NY 11369"
#                 ]
#             },
#             "phone": "+19173964225",
#             "display_phone": "(917) 396-4225",
#             "distance": 3728.5733595101765
#         }
#     ],
#     "total": 795,
#     "region": {
#         "center": {
#             "longitude": -73.92219543457031,
#             "latitude": 40.76688875374591
#         }
#     }
# }

# %%
businesses = parsed["businesses"]

for business in businesses:
    print("Name:", business["name"])
    print("Rating:", business["rating"])
    print("Address:", " ".join(business["location"]["display_address"]))
    print("Phone:", business["phone"])
    print("\n")

# %%
# extract business reviews by ID
id = business["id"]

# %%
url = "https://api.yelp.com/v3/businesses/" + id + "/reviews"
req = requests.get(url, headers=headers)
parsed = json.loads(req.text)

# %%
print(json.dumps(parsed, indent=4))

# %%
reviews = parsed["reviews"]

# %%
for review in reviews:
    print("User:", review["user"]["name"], "Rating:", review["rating"], "Review:", review["text"], "\n")

# %%
import requests
import json

api_key = 'copy_your_yelp_api_key_here'
headers = {'Authorization': 'Bearer %s' % api_key}

url = 'https://api.yelp.com/v3/businesses/search'
params = {'term':'bookstore','location':'New York City'}

req = requests.get(url, params=params, headers=headers)

parsed = json.loads(req.text)

businesses = parsed["businesses"]

for business in businesses:
    print("Name:", business["name"])
    print("Rating:", business["rating"])
    print("Address:", " ".join(business["location"]["display_address"]))
    print("Phone:", business["phone"])
    print("\n")

    id = business["id"]

    url="https://api.yelp.com/v3/businesses/" + id + "/reviews"

    req = requests.get(url, headers=headers)

    parsed = json.loads(req.text)

    reviews = parsed["reviews"]

    print("--- Reviews ---")

    for review in reviews:
        print("User:", review["user"]["name"], "Rating:", review["rating"], "Review:", review["text"], "\n")
