# %%
import json
import requests
import csv 
import pandas as pd

### found here: https://www.yelp.com/developers/v3/manage_app?
api_key = 'TODO'

# %%
def parse_yelp_business_data(businesses, params):
    csvData = []
    for business in businesses: 
        data = []
        for param in params: 
            try:
                if (param == 'coordinates'):
                    coordinates = business[param]
                    data.append(coordinates['latitude'])
                    data.append(coordinates['longitude'])
                elif (param == 'location'):
                    location = business[param]
                    address = location['address1']
                    city = location['city']
                    zipcode = location['zip_code']
                    state = location['state']
                    country = location['country']
                    data.extend([address, city, zipcode, state, country])
                elif (param == 'categories'):
                    categories = business[param]
                    cats = []
                    for category in categories:
                        cats.append(category['alias'])
                    data.append(','.join([str(x) for x in cats]))
                else:    
                    value = business[param]
                    data.append(value)
            except:
                data.append('MISSING')
        if ( len(data) != 0):
            csvData.append(data)
    return csvData

# %%
def get_parsed_json_yelp_data(api_key, term, borough, limit, offset):
    headers = {'Authorization': 'Bearer %s' % api_key}
    url = 'https://api.yelp.com/v3/businesses/search'
    params = {'term': term, 'location': borough, 'limit': limit, 'offset': offset}
    req = requests.get(url, params=params, headers=headers)
    parsed = json.loads(req.text)
    return parsed

def get_parsed_json_yelp_data_lat_long(api_key, term, limit, offset, latlong, radius):
    headers = {'Authorization': 'Bearer %s' % api_key}
    url = 'https://api.yelp.com/v3/businesses/search'
    params = {'term': term, 'latitude': latlong[0], 'longitude': latlong[1], 'radius': radius, 
              'limit': limit, 'offset': offset }
    req = requests.get(url, params=params, headers=headers)
    parsed = json.loads(req.text)
    return parsed

# %%
def create_empty_csv_file(name, header): 
    with open(name, 'w', newline='', encoding='utf-8') as csvFile:
        writer = csv.writer(csvFile)
        writer.writerows([header])
    csvFile.close()
    
def append_to_csv_file(name, csvData):
    file_type = '.csv'
    with open(name + file_type, 'a', newline='', encoding='utf-8') as csvFile:
        writer = csv.writer(csvFile)
        try: 
            writer.writerows(csvData)
        except Exception as e:
            print(csvData)
            print(e)
    csvFile.close()

# %%
## Manhattan - 500 meter radius circles that cover it
latlongs = [
    [40.8702861,-73.9158498],[40.8664998,-73.9264616],[40.8630596,-73.9193376],[40.8576068,-73.9269766],
    [40.8553996,-73.9365037],[40.8494268,-73.9309248],[40.8476774,-73.9417123],[40.8419636,-73.9356183],
    [40.8390491,-73.944373],[40.8336592,-73.9390515],[40.8313213,-73.9487504],[40.8262098,-73.9397938],
    [40.823417,-73.9500076],[40.8197867,-73.9395633],[40.8174483,-73.9575019],[40.8158244,-73.9479747],
    [40.812966,-73.9388768],[40.8095232,-73.9556137],[40.7869768,-73.9435973],[40.807509,-73.946172],
    [40.8000371,-73.9341564],[40.8117967,-73.9649689],[40.803936,-73.9633383],[40.8015321,-73.9537251],
    [40.8051704,-73.9378466],[40.799323,-73.945228],[40.79367,-73.9370742],[40.7958143,-73.9613644],[40.79302,-73.948232],
    [40.798729,-73.9705936],[40.7911915,-73.969907],[40.7922312,-73.9787475],[40.7840431,-73.9738552],
    [40.7856677,-73.9831249],[40.7774441,-73.97849],[40.779069,-73.9872448],[40.7863254,-73.9535711],
    [40.7789815,-73.9582059],[40.7797614,-73.9479063],[40.7718318,-73.9593769],[40.7669565,-73.9549138],
    [40.7735868,-73.9490772],[40.7752659,-73.9688835],[40.7670757,-73.9668236],[40.7613549,-73.9613304],
    [40.770958,-73.9844276],[40.773493,-73.9937831],[40.7660176,-73.993354],[40.7642707,-73.9814235],
    [40.755819,-73.9652873],[40.76155,-73.9730121],[40.7606398,-73.9885474],[40.7559588,-73.9803935],
    [40.753098,-73.9735271],[40.7475664,-73.9672738],[40.7593349,-73.9989454],[40.7538085,-73.9907915],
    [40.7486068,-73.9829809],[40.7450955,-73.9753419],[40.7532234,-74.0023786],[40.74826,-73.9957696],
    [40.7445535,-73.9891607],[40.7474797,-74.0055543],[40.7399364,-74.0056738],[40.7414322,-73.9982066],
    [40.7403917,-73.9822421],[40.7369449,-73.9742598],[40.7366848,-73.9905676],[40.733628,-73.999494],
    [40.7323272,-74.0092787],[40.7264734,-74.0018115],[40.7289451,-73.9914259],[40.7321971,-73.9818129],
    [40.7283597,-73.9735732],[40.7251075,-73.9824137],[40.724522,-74.0113811],[40.7223477,-73.9929199],
    [40.7191879,-74.0029697],[40.7171062,-74.0121536],[40.7115113,-74.0039997],[40.7149317,-73.9946365],
    [40.7177568,-73.9852027],[40.7097547,-74.0143852],[40.7047245,-74.0061454],[40.7025698,-74.0160084],
    [40.7088886,-73.9971332],[40.7112959,-73.9871769],[40.7136712,-73.9784622],[40.7208272,-73.976059]
]

# %%
params = ['id','alias','name','is_closed','review_count','rating','price',
#          'transactions',
          'categories',         
          'coordinates',
          'location']

params_lat_long = ['id','alias','name','is_closed','review_count','rating','price',
#          'transactions',
          'categories',         
          'coordinates',
          'latitude', 'longitude','radius']

header = ['id','alias','name','is_closed','review_count','rating','price',
#          'transactions',
          'categories',
          'latitude','longitude',
          'address','city','zipcode','state','country']

file_name = 'restaurant_data2'
term = 'Restaurants'
borough = 'Brooklyn, NY'
offset = 0
total = 0
max_limit = 50 
limit = max_limit
radius = 500

create_empty_csv_file(file_name, header)

for latlong in latlongs:    
    print("Fetching for Latitude: {}, Longitude: {}".format(latlong[0], latlong[1]))
    offset = 0
    while (offset <= total): 
        try: 
            parsed = get_parsed_json_yelp_data_lat_long(api_key, term, limit, offset, latlong, radius)
            total = parsed['total']
            businesses = parsed['businesses']
            csvData = parse_yelp_business_data(businesses, params)
            print("Offset: {}, Total: {}, Businesses: {}".format(offset, total, len(businesses)))
            append_to_csv_file(file_name,csvData)
            offset += limit
        except Exception as e:
            print("Issue while appending parsed data: {}".format(parsed))
            raise e
        
print("Finished Scraping Here")
# Out:
# Fetching for Latitude: 40.8702861, Longitude: -73.9158498
# Offset: 0, Total: 37, Businesses: 37
# Fetching for Latitude: 40.8664998, Longitude: -73.9264616
# Offset: 0, Total: 60, Businesses: 50
# Offset: 50, Total: 60, Businesses: 10
# Fetching for Latitude: 40.8630596, Longitude: -73.9193376
# Offset: 0, Total: 69, Businesses: 50
# Offset: 50, Total: 69, Businesses: 19
# Fetching for Latitude: 40.8576068, Longitude: -73.9269766
# Offset: 0, Total: 51, Businesses: 50
# Offset: 50, Total: 51, Businesses: 1
# Fetching for Latitude: 40.8553996, Longitude: -73.9365037
# Offset: 0, Total: 58, Businesses: 50
# Offset: 50, Total: 58, Businesses: 8
# Fetching for Latitude: 40.8494268, Longitude: -73.9309248
# Offset: 0, Total: 59, Businesses: 50
# Offset: 50, Total: 59, Businesses: 9
# Fetching for Latitude: 40.8476774, Longitude: -73.9417123
# Offset: 0, Total: 60, Businesses: 50
# Offset: 50, Total: 60, Businesses: 10
# Fetching for Latitude: 40.8419636, Longitude: -73.9356183
# Offset: 0, Total: 65, Businesses: 50
# Offset: 50, Total: 65, Businesses: 15
# Fetching for Latitude: 40.8390491, Longitude: -73.944373
# Offset: 0, Total: 58, Businesses: 50
# Offset: 50, Total: 58, Businesses: 8
# Fetching for Latitude: 40.8336592, Longitude: -73.9390515
# Offset: 0, Total: 54, Businesses: 50
# Offset: 50, Total: 54, Businesses: 4
# Fetching for Latitude: 40.8313213, Longitude: -73.9487504
# Offset: 0, Total: 74, Businesses: 50
# Offset: 50, Total: 74, Businesses: 24
# Fetching for Latitude: 40.8262098, Longitude: -73.9397938
# Offset: 0, Total: 54, Businesses: 50
# Offset: 50, Total: 54, Businesses: 4
# Fetching for Latitude: 40.823417, Longitude: -73.9500076
# Offset: 0, Total: 106, Businesses: 50
# Offset: 50, Total: 106, Businesses: 50
# Offset: 100, Total: 106, Businesses: 6
# Fetching for Latitude: 40.8197867, Longitude: -73.9395633
# Offset: 0, Total: 61, Businesses: 50
# Offset: 50, Total: 61, Businesses: 11
# Fetching for Latitude: 40.8174483, Longitude: -73.9575019
# Offset: 0, Total: 63, Businesses: 50
# Offset: 50, Total: 63, Businesses: 13
# Fetching for Latitude: 40.8158244, Longitude: -73.9479747
# Offset: 0, Total: 66, Businesses: 50
# Offset: 50, Total: 66, Businesses: 16
# Fetching for Latitude: 40.812966, Longitude: -73.9388768
# Offset: 0, Total: 36, Businesses: 36
# Fetching for Latitude: 40.8095232, Longitude: -73.9556137
# Offset: 0, Total: 98, Businesses: 50
# Offset: 50, Total: 98, Businesses: 48
# Fetching for Latitude: 40.7869768, Longitude: -73.9435973
# Offset: 0, Total: 79, Businesses: 50
# Offset: 50, Total: 79, Businesses: 29
# Fetching for Latitude: 40.807509, Longitude: -73.946172
# Offset: 0, Total: 76, Businesses: 50
# Offset: 50, Total: 76, Businesses: 26
# Fetching for Latitude: 40.8000371, Longitude: -73.9341564
# Offset: 0, Total: 59, Businesses: 50
# Offset: 50, Total: 59, Businesses: 9
# Fetching for Latitude: 40.8117967, Longitude: -73.9649689
# Offset: 0, Total: 26, Businesses: 26
# Fetching for Latitude: 40.803936, Longitude: -73.9633383
# Offset: 0, Total: 136, Businesses: 50
# Offset: 50, Total: 136, Businesses: 50
# Offset: 100, Total: 136, Businesses: 36
# Fetching for Latitude: 40.8015321, Longitude: -73.9537251
# Offset: 0, Total: 73, Businesses: 50
# Offset: 50, Total: 73, Businesses: 23
# Fetching for Latitude: 40.8051704, Longitude: -73.9378466
# Offset: 0, Total: 45, Businesses: 45
# Fetching for Latitude: 40.799323, Longitude: -73.945228
# Offset: 0, Total: 64, Businesses: 50
# Offset: 50, Total: 64, Businesses: 14
# Fetching for Latitude: 40.79367, Longitude: -73.9370742
# Offset: 0, Total: 102, Businesses: 50
# Offset: 50, Total: 102, Businesses: 50
# Offset: 100, Total: 102, Businesses: 2
# Fetching for Latitude: 40.7958143, Longitude: -73.9613644
# Offset: 0, Total: 61, Businesses: 50
# Offset: 50, Total: 61, Businesses: 11
# Fetching for Latitude: 40.79302, Longitude: -73.948232
# Offset: 0, Total: 88, Businesses: 50
# Offset: 50, Total: 88, Businesses: 38
# Fetching for Latitude: 40.798729, Longitude: -73.9705936
# Offset: 0, Total: 108, Businesses: 50
# Offset: 50, Total: 108, Businesses: 50
# Offset: 100, Total: 108, Businesses: 8
# Fetching for Latitude: 40.7911915, Longitude: -73.969907
# Offset: 0, Total: 111, Businesses: 50
# Offset: 50, Total: 111, Businesses: 50
# Offset: 100, Total: 111, Businesses: 11
# Fetching for Latitude: 40.7922312, Longitude: -73.9787475
# Offset: 0, Total: 45, Businesses: 45
# Fetching for Latitude: 40.7840431, Longitude: -73.9738552
# Offset: 0, Total: 150, Businesses: 50
# Offset: 50, Total: 150, Businesses: 50
# Offset: 100, Total: 150, Businesses: 50
# Offset: 150, Total: 150, Businesses: 0
# Fetching for Latitude: 40.7856677, Longitude: -73.9831249
# Offset: 0, Total: 39, Businesses: 39
# Fetching for Latitude: 40.7774441, Longitude: -73.97849
# Offset: 0, Total: 153, Businesses: 50
# Offset: 50, Total: 153, Businesses: 50
# Offset: 100, Total: 153, Businesses: 50
# Offset: 150, Total: 153, Businesses: 3
# Fetching for Latitude: 40.779069, Longitude: -73.9872448
# Offset: 0, Total: 27, Businesses: 27
# Fetching for Latitude: 40.7863254, Longitude: -73.9535711
# Offset: 0, Total: 86, Businesses: 50
# Offset: 50, Total: 86, Businesses: 36
# Fetching for Latitude: 40.7789815, Longitude: -73.9582059
# Offset: 0, Total: 135, Businesses: 50
# Offset: 50, Total: 135, Businesses: 50
# Offset: 100, Total: 135, Businesses: 35
# Fetching for Latitude: 40.7797614, Longitude: -73.9479063
# Offset: 0, Total: 143, Businesses: 50
# Offset: 50, Total: 143, Businesses: 50
# Offset: 100, Total: 143, Businesses: 43
# Fetching for Latitude: 40.7718318, Longitude: -73.9593769
# Offset: 0, Total: 210, Businesses: 50
# Offset: 50, Total: 210, Businesses: 50
# Offset: 100, Total: 210, Businesses: 50
# Offset: 150, Total: 210, Businesses: 50
# Offset: 200, Total: 210, Businesses: 10
# Fetching for Latitude: 40.7669565, Longitude: -73.9549138
# Offset: 0, Total: 181, Businesses: 50
# Offset: 50, Total: 181, Businesses: 50
# Offset: 100, Total: 181, Businesses: 50
# Offset: 150, Total: 181, Businesses: 31
# Fetching for Latitude: 40.7735868, Longitude: -73.9490772
# Offset: 0, Total: 135, Businesses: 50
# Offset: 50, Total: 135, Businesses: 50
# Offset: 100, Total: 135, Businesses: 35
# Fetching for Latitude: 40.7752659, Longitude: -73.9688835
# Offset: 0, Total: 8, Businesses: 8
# Fetching for Latitude: 40.7670757, Longitude: -73.9668236
# Offset: 0, Total: 140, Businesses: 50
# Offset: 50, Total: 140, Businesses: 50
# Offset: 100, Total: 140, Businesses: 40
# Fetching for Latitude: 40.7613549, Longitude: -73.9613304
# Offset: 0, Total: 172, Businesses: 50
# Offset: 50, Total: 172, Businesses: 50
# Offset: 100, Total: 172, Businesses: 50
# Offset: 150, Total: 172, Businesses: 22
# Fetching for Latitude: 40.770958, Longitude: -73.9844276
# Offset: 0, Total: 212, Businesses: 50
# Offset: 50, Total: 212, Businesses: 50
# Offset: 100, Total: 212, Businesses: 50
# Offset: 150, Total: 212, Businesses: 50
# Offset: 200, Total: 212, Businesses: 12
# Fetching for Latitude: 40.773493, Longitude: -73.9937831
# Offset: 0, Total: 21, Businesses: 21
# Fetching for Latitude: 40.7660176, Longitude: -73.993354
# Offset: 0, Total: 198, Businesses: 50
# Offset: 50, Total: 198, Businesses: 50
# Offset: 100, Total: 198, Businesses: 50
# Offset: 150, Total: 198, Businesses: 48
# Fetching for Latitude: 40.7642707, Longitude: -73.9814235
# Offset: 0, Total: 451, Businesses: 50
# Offset: 50, Total: 451, Businesses: 50
# Offset: 100, Total: 451, Businesses: 50
# Offset: 150, Total: 451, Businesses: 50
# Offset: 200, Total: 451, Businesses: 50
# Offset: 250, Total: 451, Businesses: 50
# Offset: 300, Total: 451, Businesses: 50
# Offset: 350, Total: 451, Businesses: 50
# Offset: 400, Total: 451, Businesses: 50
# Offset: 450, Total: 451, Businesses: 1
# Fetching for Latitude: 40.755819, Longitude: -73.9652873
# Offset: 0, Total: 254, Businesses: 50
# Offset: 50, Total: 254, Businesses: 50
# Offset: 100, Total: 254, Businesses: 50
# Offset: 150, Total: 254, Businesses: 50
# Offset: 200, Total: 254, Businesses: 50
# Offset: 250, Total: 254, Businesses: 4
# Fetching for Latitude: 40.76155, Longitude: -73.9730121
# Offset: 0, Total: 401, Businesses: 50
# Offset: 50, Total: 401, Businesses: 50
# Offset: 100, Total: 401, Businesses: 50
# Offset: 150, Total: 401, Businesses: 50
# Offset: 200, Total: 401, Businesses: 50
# Offset: 250, Total: 401, Businesses: 50
# Offset: 300, Total: 401, Businesses: 50
# Offset: 350, Total: 401, Businesses: 50
# Offset: 400, Total: 401, Businesses: 1
# Fetching for Latitude: 40.7606398, Longitude: -73.9885474
# Offset: 0, Total: 566, Businesses: 50
# Offset: 50, Total: 566, Businesses: 50
# Offset: 100, Total: 566, Businesses: 50
# Offset: 150, Total: 566, Businesses: 50
# Offset: 200, Total: 566, Businesses: 50
# Offset: 250, Total: 566, Businesses: 50
# Offset: 300, Total: 566, Businesses: 50
# Offset: 350, Total: 566, Businesses: 50
# Offset: 400, Total: 566, Businesses: 50
# Offset: 450, Total: 566, Businesses: 50
# Offset: 500, Total: 566, Businesses: 50
# Offset: 550, Total: 566, Businesses: 16
# Fetching for Latitude: 40.7559588, Longitude: -73.9803935
# Offset: 0, Total: 600, Businesses: 50
# Offset: 50, Total: 600, Businesses: 50
# Offset: 100, Total: 600, Businesses: 50
# Offset: 150, Total: 600, Businesses: 50
# Offset: 200, Total: 600, Businesses: 50
# Offset: 250, Total: 600, Businesses: 50
# Offset: 300, Total: 600, Businesses: 50
# Offset: 350, Total: 600, Businesses: 50
# Offset: 400, Total: 600, Businesses: 50
# Offset: 450, Total: 600, Businesses: 50
# Offset: 500, Total: 600, Businesses: 50
# Offset: 550, Total: 600, Businesses: 50
# Offset: 600, Total: 600, Businesses: 0
# Fetching for Latitude: 40.753098, Longitude: -73.9735271
# Offset: 0, Total: 522, Businesses: 50
# Offset: 50, Total: 522, Businesses: 50
# Offset: 100, Total: 522, Businesses: 50
# Offset: 150, Total: 522, Businesses: 50
# Offset: 200, Total: 522, Businesses: 50
# Offset: 250, Total: 522, Businesses: 50
# Offset: 300, Total: 522, Businesses: 50
# Offset: 350, Total: 522, Businesses: 50
# Offset: 400, Total: 522, Businesses: 50
# Offset: 450, Total: 522, Businesses: 50
# Offset: 500, Total: 522, Businesses: 22
# Fetching for Latitude: 40.7475664, Longitude: -73.9672738
# Offset: 0, Total: 49, Businesses: 49
# Fetching for Latitude: 40.7593349, Longitude: -73.9989454
# Offset: 0, Total: 122, Businesses: 50
# Offset: 50, Total: 122, Businesses: 50
# Offset: 100, Total: 122, Businesses: 22
# Fetching for Latitude: 40.7538085, Longitude: -73.9907915
# Offset: 0, Total: 584, Businesses: 50
# Offset: 50, Total: 584, Businesses: 50
# Offset: 100, Total: 584, Businesses: 50
# Offset: 150, Total: 584, Businesses: 50
# Offset: 200, Total: 584, Businesses: 50
# Offset: 250, Total: 584, Businesses: 50
# Offset: 300, Total: 584, Businesses: 50
# Offset: 350, Total: 584, Businesses: 50
# Offset: 400, Total: 584, Businesses: 50
# Offset: 450, Total: 584, Businesses: 50
# Offset: 500, Total: 584, Businesses: 50
# Offset: 550, Total: 584, Businesses: 34
# Fetching for Latitude: 40.7486068, Longitude: -73.9829809
# Offset: 0, Total: 524, Businesses: 50
# Offset: 50, Total: 524, Businesses: 50
# Offset: 100, Total: 524, Businesses: 50
# Offset: 150, Total: 524, Businesses: 50
# Offset: 200, Total: 524, Businesses: 50
# Offset: 250, Total: 524, Businesses: 50
# Offset: 300, Total: 524, Businesses: 50
# Offset: 350, Total: 524, Businesses: 50
# Offset: 400, Total: 524, Businesses: 50
# Offset: 450, Total: 524, Businesses: 50
# Offset: 500, Total: 524, Businesses: 24
# Fetching for Latitude: 40.7450955, Longitude: -73.9753419
# Offset: 0, Total: 213, Businesses: 50
# Offset: 50, Total: 213, Businesses: 50
# Offset: 100, Total: 213, Businesses: 50
# Offset: 150, Total: 213, Businesses: 50
# Offset: 200, Total: 213, Businesses: 13
# Fetching for Latitude: 40.7532234, Longitude: -74.0023786
# Offset: 0, Total: 106, Businesses: 50
# Offset: 50, Total: 106, Businesses: 50
# Offset: 100, Total: 106, Businesses: 6
# Fetching for Latitude: 40.74826, Longitude: -73.9957696
# Offset: 0, Total: 336, Businesses: 50
# Offset: 50, Total: 336, Businesses: 50
# Offset: 100, Total: 336, Businesses: 50
# Offset: 150, Total: 336, Businesses: 50
# Offset: 200, Total: 336, Businesses: 50
# Offset: 250, Total: 336, Businesses: 50
# Offset: 300, Total: 336, Businesses: 36
# Fetching for Latitude: 40.7445535, Longitude: -73.9891607
# Offset: 0, Total: 532, Businesses: 50
# Offset: 50, Total: 532, Businesses: 50
# Offset: 100, Total: 532, Businesses: 50
# Offset: 150, Total: 532, Businesses: 50
# Offset: 200, Total: 532, Businesses: 50
# Offset: 250, Total: 532, Businesses: 50
# Offset: 300, Total: 532, Businesses: 50
# Offset: 350, Total: 532, Businesses: 50
# Offset: 400, Total: 532, Businesses: 50
# Offset: 450, Total: 532, Businesses: 50
# Offset: 500, Total: 532, Businesses: 32
# Fetching for Latitude: 40.7474797, Longitude: -74.0055543
# Offset: 0, Total: 152, Businesses: 50
# Offset: 50, Total: 152, Businesses: 50
# Offset: 100, Total: 152, Businesses: 50
# Offset: 150, Total: 152, Businesses: 2
# Fetching for Latitude: 40.7399364, Longitude: -74.0056738
# Offset: 0, Total: 283, Businesses: 50
# Offset: 50, Total: 283, Businesses: 50
# Offset: 100, Total: 283, Businesses: 50
# Offset: 150, Total: 283, Businesses: 50
# Offset: 200, Total: 283, Businesses: 50
# Offset: 250, Total: 283, Businesses: 33
# Fetching for Latitude: 40.7414322, Longitude: -73.9982066
# Offset: 0, Total: 280, Businesses: 50
# Offset: 50, Total: 280, Businesses: 50
# Offset: 100, Total: 280, Businesses: 50
# Offset: 150, Total: 280, Businesses: 50
# Offset: 200, Total: 280, Businesses: 50
# Offset: 250, Total: 280, Businesses: 30
# Fetching for Latitude: 40.7403917, Longitude: -73.9822421
# Offset: 0, Total: 358, Businesses: 50
# Offset: 50, Total: 358, Businesses: 50
# Offset: 100, Total: 358, Businesses: 50
# Offset: 150, Total: 358, Businesses: 50
# Offset: 200, Total: 358, Businesses: 50
# Offset: 250, Total: 358, Businesses: 50
# Offset: 300, Total: 358, Businesses: 50
# Offset: 350, Total: 358, Businesses: 8
# Fetching for Latitude: 40.7369449, Longitude: -73.9742598
# Offset: 0, Total: 21, Businesses: 21
# Fetching for Latitude: 40.7366848, Longitude: -73.9905676
# Offset: 0, Total: 389, Businesses: 50
# Offset: 50, Total: 389, Businesses: 50
# Offset: 100, Total: 389, Businesses: 50
# Offset: 150, Total: 389, Businesses: 50
# Offset: 200, Total: 389, Businesses: 50
# Offset: 250, Total: 389, Businesses: 50
# Offset: 300, Total: 389, Businesses: 50
# Offset: 350, Total: 389, Businesses: 39
# Fetching for Latitude: 40.733628, Longitude: -73.999494
# Offset: 0, Total: 440, Businesses: 50
# Offset: 50, Total: 440, Businesses: 50
# Offset: 100, Total: 440, Businesses: 50
# Offset: 150, Total: 440, Businesses: 50
# Offset: 200, Total: 440, Businesses: 50
# Offset: 250, Total: 440, Businesses: 50
# Offset: 300, Total: 440, Businesses: 50
# Offset: 350, Total: 440, Businesses: 50
# Offset: 400, Total: 440, Businesses: 40
# Fetching for Latitude: 40.7323272, Longitude: -74.0092787
# Offset: 0, Total: 134, Businesses: 50
# Offset: 50, Total: 134, Businesses: 50
# Offset: 100, Total: 134, Businesses: 34
# Fetching for Latitude: 40.7264734, Longitude: -74.0018115
# Offset: 0, Total: 410, Businesses: 50
# Offset: 50, Total: 410, Businesses: 50
# Offset: 100, Total: 410, Businesses: 50
# Offset: 150, Total: 410, Businesses: 50
# Offset: 200, Total: 410, Businesses: 50
# Offset: 250, Total: 410, Businesses: 50
# Offset: 300, Total: 410, Businesses: 50
# Offset: 350, Total: 410, Businesses: 50
# Offset: 400, Total: 410, Businesses: 10
# Fetching for Latitude: 40.7289451, Longitude: -73.9914259
# Offset: 0, Total: 425, Businesses: 50
# Offset: 50, Total: 425, Businesses: 50
# Offset: 100, Total: 425, Businesses: 50
# Offset: 150, Total: 425, Businesses: 50
# Offset: 200, Total: 425, Businesses: 50
# Offset: 250, Total: 425, Businesses: 50
# Offset: 300, Total: 425, Businesses: 50
# Offset: 350, Total: 425, Businesses: 50
# Offset: 400, Total: 425, Businesses: 25
# Fetching for Latitude: 40.7321971, Longitude: -73.9818129
# Offset: 0, Total: 315, Businesses: 50
# Offset: 50, Total: 315, Businesses: 50
# Offset: 100, Total: 315, Businesses: 50
# Offset: 150, Total: 315, Businesses: 50
# Offset: 200, Total: 315, Businesses: 50
# Offset: 250, Total: 315, Businesses: 50
# Offset: 300, Total: 315, Businesses: 15
# Fetching for Latitude: 40.7283597, Longitude: -73.9735732
# Offset: 0, Total: 18, Businesses: 18
# Fetching for Latitude: 40.7251075, Longitude: -73.9824137
# Offset: 0, Total: 374, Businesses: 50
# Offset: 50, Total: 374, Businesses: 50
# Offset: 100, Total: 374, Businesses: 50
# Offset: 150, Total: 374, Businesses: 50
# Offset: 200, Total: 374, Businesses: 50
# Offset: 250, Total: 374, Businesses: 50
# Offset: 300, Total: 374, Businesses: 50
# Offset: 350, Total: 374, Businesses: 24
# Fetching for Latitude: 40.724522, Longitude: -74.0113811
# Offset: 0, Total: 80, Businesses: 50
# Offset: 50, Total: 80, Businesses: 30
# Fetching for Latitude: 40.7223477, Longitude: -73.9929199
# Offset: 0, Total: 469, Businesses: 50
# Offset: 50, Total: 469, Businesses: 50
# Offset: 100, Total: 469, Businesses: 50
# Offset: 150, Total: 469, Businesses: 50
# Offset: 200, Total: 469, Businesses: 50
# Offset: 250, Total: 469, Businesses: 50
# Offset: 300, Total: 469, Businesses: 50
# Offset: 350, Total: 469, Businesses: 50
# Offset: 400, Total: 469, Businesses: 50
# Offset: 450, Total: 469, Businesses: 19
# Fetching for Latitude: 40.7191879, Longitude: -74.0029697
# Offset: 0, Total: 284, Businesses: 50
# Offset: 50, Total: 284, Businesses: 50
# Offset: 100, Total: 284, Businesses: 50
# Offset: 150, Total: 284, Businesses: 50
# Offset: 200, Total: 284, Businesses: 50
# Offset: 250, Total: 284, Businesses: 34
# Fetching for Latitude: 40.7171062, Longitude: -74.0121536
# Offset: 0, Total: 199, Businesses: 50
# Offset: 50, Total: 199, Businesses: 50
# Offset: 100, Total: 199, Businesses: 50
# Offset: 150, Total: 199, Businesses: 49
# Fetching for Latitude: 40.7115113, Longitude: -74.0039997
# Offset: 0, Total: 356, Businesses: 50
# Offset: 50, Total: 356, Businesses: 50
# Offset: 100, Total: 356, Businesses: 50
# Offset: 150, Total: 356, Businesses: 50
# Offset: 200, Total: 356, Businesses: 50
# Offset: 250, Total: 356, Businesses: 50
# Offset: 300, Total: 356, Businesses: 50
# Offset: 350, Total: 356, Businesses: 6
# Fetching for Latitude: 40.7149317, Longitude: -73.9946365
# Offset: 0, Total: 459, Businesses: 50
# Offset: 50, Total: 459, Businesses: 50
# Offset: 100, Total: 459, Businesses: 50
# Offset: 150, Total: 459, Businesses: 50
# Offset: 200, Total: 459, Businesses: 50
# Offset: 250, Total: 459, Businesses: 50
# Offset: 300, Total: 459, Businesses: 50
# Offset: 350, Total: 459, Businesses: 50
# Offset: 400, Total: 459, Businesses: 50
# Offset: 450, Total: 459, Businesses: 9
# Fetching for Latitude: 40.7177568, Longitude: -73.9852027
# Offset: 0, Total: 279, Businesses: 50
# Offset: 50, Total: 279, Businesses: 50
# Offset: 100, Total: 279, Businesses: 50
# Offset: 150, Total: 279, Businesses: 50
# Offset: 200, Total: 279, Businesses: 50
# Offset: 250, Total: 279, Businesses: 29
# Fetching for Latitude: 40.7097547, Longitude: -74.0143852
# Offset: 0, Total: 237, Businesses: 50
# Offset: 50, Total: 237, Businesses: 50
# Offset: 100, Total: 237, Businesses: 50
# Offset: 150, Total: 237, Businesses: 50
# Offset: 200, Total: 237, Businesses: 37
# Fetching for Latitude: 40.7047245, Longitude: -74.0061454
# Offset: 0, Total: 284, Businesses: 50
# Offset: 50, Total: 284, Businesses: 50
# Offset: 100, Total: 284, Businesses: 50
# Offset: 150, Total: 284, Businesses: 50
# Offset: 200, Total: 284, Businesses: 50
# Offset: 250, Total: 284, Businesses: 34
# Fetching for Latitude: 40.7025698, Longitude: -74.0160084
# Offset: 0, Total: 120, Businesses: 50
# Offset: 50, Total: 120, Businesses: 50
# Offset: 100, Total: 120, Businesses: 20
# Fetching for Latitude: 40.7088886, Longitude: -73.9971332
# Offset: 0, Total: 129, Businesses: 50
# Offset: 50, Total: 129, Businesses: 50
# Offset: 100, Total: 129, Businesses: 29
# Fetching for Latitude: 40.7112959, Longitude: -73.9871769
# Offset: 0, Total: 70, Businesses: 50
# Offset: 50, Total: 70, Businesses: 20
# Fetching for Latitude: 40.7136712, Longitude: -73.9784622
# Offset: 0, Total: 12, Businesses: 12
# Fetching for Latitude: 40.7208272, Longitude: -73.976059
# Offset: 0, Total: 30, Businesses: 30
# Finished Scraping Here

# %%
#This process has too many duplicates, let's remove them
file_name_output = file_name + '_sans_dupes' + '.csv'

df = pd.read_csv(file_name + '.csv')
df.drop_duplicates(subset=['id'], inplace=True)
df.to_csv(file_name_output, index=False)
